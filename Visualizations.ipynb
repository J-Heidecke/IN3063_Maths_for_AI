# %%
import matplotlib.pyplot as plt

task4_results = {'Task 2' : [93.8,96.9, 93.8, 93.6, 95.1, 93.8],
                'PyTorch' : [94.0, 100.0, 96.5, 94.2, 96.1, 99.0],
                'Keras': [91.5, 97.2, 91.7, 91.7, 91.8, 97.5]}

plt.plot(task4_results['Task 2'], label = 'Task 2')
plt.plot(task4_results['PyTorch'], label = 'PyTorch')
plt.plot(task4_results['Keras'], label = 'Keras')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., frameon=False)

# %%
task4_results2 = {'Task 2' : [96.7, 97.1, 93.8],
                'PyTorch' : [99.8, 99.9, 92.8],
                'Keras': [97.2, 97.2, 98.1]}

plt.plot(task4_results2['Task 2'], label = 'Task 2')
plt.plot(task4_results2['PyTorch'], label = 'PyTorch')
plt.plot(task4_results2['Keras'], label = 'Keras')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., frameon=False)

# %%
task3_results = [0.0, 96.0, 97.2, 97.9, 97.9, 98.6, 98.5, 98.8, 99.1, 99.2, 99.0, 99.2, 99.5, 98.8, 99.5, 99.6, 99.8, 99.6, 99.3, 99.5, 99.2, 99.5, 99.7, 99.5, 99.7, 99.7 ]
plt.plot(task3_results)
plt.xlabel('Epoch')
plt.ylabel('Accuracy / %')
# Out:
# Text(0, 0.5, 'Accuracy / %')

# %%
results_dropout = {}
results_dropout['0.1'] = 96.5
results_dropout['0.2'] = 96.1
results_dropout['0.3'] = 96.4
results_dropout['0.4'] = 96.2
results_dropout['0.5'] = 95.7
results_dropout['0.6'] = 96.0
results_dropout['0.7'] = 96.2
results_dropout['0.8'] = 96.3
results_dropout['0.9'] = 96.0
results_dropout['1.0'] = 95.7

plt.plot(results_dropout.keys(), results_dropout.values())
plt.ylabel('Accuracy / %')
plt.xlabel('P-value')
# Out:
# Text(0.5, 0, 'P-value')

# %%
task3_results2 = [96.0, 97.2, 97.9, 97.9, 98.6, 98.5, 98.8, 99.1, 99.2, 99.0, 99.2, 99.5, 98.8, 99.5, 99.6, 99.8, 99.6, 99.3, 99.5, 99.2, 99.5, 99.7, 99.5, 99.7, 99.7 ]
plt.plot(task3_results2)
plt.xlabel('Epoch')
plt.ylabel('Accuracy / %')
# Out:
# Text(0, 0.5, 'Accuracy / %')
